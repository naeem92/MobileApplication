# %% [markdown]
# <a href="https://colab.research.google.com/github/naeem92/MobileApplication/blob/main/Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
csv_path = "/content/drive/MyDrive/AI-Data.csv"
df = pd.read_csv(csv_path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 799 entries, 0 to 798
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    798 non-null    object
#  1   NationalITy               799 non-null    object
#  2   PlaceofBirth              799 non-null    object
#  3   StageID                   799 non-null    object
#  4   GradeID                   799 non-null    object
#  5   SectionID                 799 non-null    object
#  6   Topic                     799 non-null    object
#  7   Semester                  798 non-null    object
#  8   Relation                  799 non-null    object
#  9   raisedhands               799 non-null    int64
#  10  VisITedResources          799 non-null    int64
#  11  AnnouncementsView         799 non-null    int64
#  12  Discussion                799 non-null    int64
# ...

# %%
missing_values = df.isnull().any(axis=1)
missing_indices = df.index[missing_values]
print(missing_indices)
# Out:
# Int64Index([90, 155], dtype='int64')

# %%
df['gender'] = df ['gender'].fillna('M')
df['Semester'] = df ['Semester'].fillna('S')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 799 entries, 0 to 798
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    799 non-null    object
#  1   NationalITy               799 non-null    object
#  2   PlaceofBirth              799 non-null    object
#  3   StageID                   799 non-null    object
#  4   GradeID                   799 non-null    object
#  5   SectionID                 799 non-null    object
#  6   Topic                     799 non-null    object
#  7   Semester                  799 non-null    object
#  8   Relation                  799 non-null    object
#  9   raisedhands               799 non-null    int64
#  10  VisITedResources          799 non-null    int64
#  11  AnnouncementsView         799 non-null    int64
#  12  Discussion                799 non-null    int64
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 794    False
# 795    False
# 796    False
# 797    False
# 798    False
# Length: 799, dtype: bool

# %%
target_column = 'PlaceofBirth'
df[target_column] = df[target_column].str.lower()
print(df)
# Out:
#     gender NationalITy PlaceofBirth     StageID GradeID SectionID   Topic  \
# 0        M          KW       kuwait  lowerlevel    G-04         A      IT
# 1        M          KW       kuwait  lowerlevel    G-05         A      IT
# 2        M          KW       kuwait  lowerlevel    G-04         A      IT
# 3        M          KW       kuwait  lowerlevel    G-04         A      IT
# 4        M          KW       kuwait  lowerlevel    G-04         A      IT
# ..     ...         ...          ...         ...     ...       ...     ...
# 794      M         USA          usa  HighSchool    G-08         B  Arabic
# 795      M         USA          usa  HighSchool    G-09         B  Arabic
# 796      M         USA          usa  HighSchool    G-10         B  Arabic
# 797      M         USA          usa  HighSchool    G-11         B  Arabic
# 798      M         USA          usa  HighSchool    G-02         B  Arabic
#
#     Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# ...

# %%
target_column = 'PlaceofBirth'
df[target_column] = df[target_column].str.upper()
print(df)
# Out:
#     gender NationalITy PlaceofBirth     StageID GradeID SectionID   Topic  \
# 0        M          KW       KUWAIT  lowerlevel    G-04         A      IT
# 1        M          KW       KUWAIT  lowerlevel    G-05         A      IT
# 2        M          KW       KUWAIT  lowerlevel    G-04         A      IT
# 3        M          KW       KUWAIT  lowerlevel    G-04         A      IT
# 4        M          KW       KUWAIT  lowerlevel    G-04         A      IT
# ..     ...         ...          ...         ...     ...       ...     ...
# 794      M         USA          USA  HighSchool    G-08         B  Arabic
# 795      M         USA          USA  HighSchool    G-09         B  Arabic
# 796      M         USA          USA  HighSchool    G-10         B  Arabic
# 797      M         USA          USA  HighSchool    G-11         B  Arabic
# 798      M         USA          USA  HighSchool    G-02         B  Arabic
#
#     Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# ...

# %%
df.corr()
# Out:
# <ipython-input-33-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    raisedhands  VisITedResources  AnnouncementsView  \
# raisedhands           1.000000          0.543433           0.492278
# VisITedResources      0.543433          1.000000           0.426747
# AnnouncementsView     0.492278          0.426747           1.000000
# Discussion            0.249515          0.173757           0.312506
#
#                    Discussion
# raisedhands          0.249515
# VisITedResources     0.173757
# AnnouncementsView    0.312506
# Discussion           1.000000

# %%
df["AnnouncementsView"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Discussion"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["VisITedResources"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["AnnouncementsView"].plot(kind = 'pie')
# Out:
# <Axes: ylabel='AnnouncementsView'>

# %%
df["Discussion"].plot(kind = 'pie')
# Out:
# <Axes: ylabel='Discussion'>

# %%
df["VisITedResources"].plot(kind = 'pie')
# Out:
# <Axes: ylabel='VisITedResources'>

# %%
df.plot(kind = 'scatter', x = 'raisedhands', y = 'AnnouncementsView')
# Out:
# <Axes: xlabel='raisedhands', ylabel='AnnouncementsView'>

# %%
df.plot(kind = 'scatter', x = 'raisedhands', y = 'Discussion')
# Out:
# <Axes: xlabel='raisedhands', ylabel='Discussion'>
